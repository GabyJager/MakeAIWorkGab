# %%
import numpy as np
import scipy as cp
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
df = pd.read_csv("./data.csv", na_values=['?', "undefined"])
display(df)

df.info()
df.describe()

df["bmi"] = round(df["mass"]/(df["length"]/100)**2, 2)

for x in df.index:
  if df.loc[x, "lifespan"] < 0:
    df.drop(x, inplace = True)

df["lifespan"]>1
df.describe()

duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
df = df.drop_duplicates()

print(df.isnull().sum())
df = df.dropna()

df = df.drop(['length', 'mass'], axis=1)
df.head()
# Out:
#       genetic  length   mass  exercise  smoking  alcohol  sugar  lifespan
# 0        73.9   185.0   99.7       0.9      0.0      2.4    6.9      73.1
# 1        86.0   172.0  105.4       1.8      8.1      0.4    4.2      85.0
# 2        83.3   176.0  111.4       1.1      0.8      4.6    7.5      81.6
# 3        82.8   164.0  111.4       4.7     11.8      1.0    2.9      81.0
# 4        78.7   178.0   71.6       1.5      8.3      4.9    5.5      75.0
# ...       ...     ...    ...       ...      ...      ...    ...       ...
# 4091     80.3   176.0  115.9       3.7      0.1      5.6    5.8      80.7
# 4092     75.3   162.0  129.6       3.6      6.2      5.6    7.6      71.1
# 4093     93.1   189.0  115.3       2.7      9.4      4.9    6.6      90.0
# 4094     77.9   170.0   90.8       2.3     13.2      0.8    6.2      75.9
# 4095    101.3   188.0  129.2       1.2      8.2      6.0    6.2      96.9
#
# [4096 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4096 entries, 0 to 4095
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genetic   4095 non-null   float64
#  1   length    4093 non-null   float64
#  2   mass      4094 non-null   float64
#  3   exercise  4095 non-null   float64
#  4   smoking   4096 non-null   float64
#  5   alcohol   4094 non-null   float64
#  6   sugar     4095 non-null   float64
#  7   lifespan  4096 non-null   float64
# dtypes: float64(8)
# memory usage: 256.1 KB
# number of duplicate rows:  (0, 9)
# genetic     1
# length      3
# mass        2
# exercise    1
# smoking     0
# alcohol     2
# sugar       1
# lifespan    0
# bmi         5
# dtype: int64
#    genetic  exercise  smoking  alcohol  sugar  lifespan    bmi
# 0     73.9       0.9      0.0      2.4    6.9      73.1  29.13
# 1     86.0       1.8      8.1      0.4    4.2      85.0  35.63
# 2     83.3       1.1      0.8      4.6    7.5      81.6  35.96
# 3     82.8       4.7     11.8      1.0    2.9      81.0  41.42
# 4     78.7       1.5      8.3      4.9    5.5      75.0  22.60

# %%
X = df.iloc[:, 1:]
#X = df.iloc['smoking', 'bmi', 'genetic', "exercise", "alcohol", "sugar" ]]
y = df['lifespan']
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=100)

forest = RandomForestClassifier(n_estimators=100, random_state=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       2 #X = df.iloc['smoking', 'bmi', 'genetic', "exercise", "alcohol", "sugar" ]]
#       3 y = df['lifespan']
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=100)
#       6 forest = RandomForestClassifier(n_estimators=100, random_state=100)
#
# File ~\MakeAIWorkGab\env\lib\site-packages\sklearn\model_selection\_split.py:2583, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2579         CVClass = ShuffleSplit
#    2581     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2583     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2585 return list(
#    2586     chain.from_iterable(
#    2587         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2588     )
#    2589 )
#
# File ~\MakeAIWorkGab\env\lib\site-packages\sklearn\model_selection\_split.py:1689, in BaseShuffleSplit.split(self, X, y, groups)
#    1659 """Generate indices to split data into training and test set.
#    1660
#    1661 Parameters
#    (...)
#    1686 to an integer.
#    1687 """
#    1688 X, y, groups = indexable(X, y, groups)
# -> 1689 for train, test in self._iter_indices(X, y, groups):
#    1690     yield train, test
#
# File ~\MakeAIWorkGab\env\lib\site-packages\sklearn\model_selection\_split.py:2078, in StratifiedShuffleSplit._iter_indices(self, X, y, groups)
#    2076 class_counts = np.bincount(y_indices)
#    2077 if np.min(class_counts) < 2:
# -> 2078     raise ValueError(
#    2079         "The least populated class in y has only 1"
#    2080         " member, which is too few. The minimum"
#    2081         " number of groups for any class cannot"
#    2082         " be less than 2."
#    2083     )
#    2085 if n_train < n_classes:
#    2086     raise ValueError(
#    2087         "The train_size = %d should be greater or "
#    2088         "equal to the number of classes = %d" % (n_train, n_classes)
#    2089     )
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %%
forest.fit(X_train,y_train)
predictions = forest.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 forest.fit(X_train,y_train)
#       2 predictions = forest.predict(X_test)
#
# NameError: name 'forest' is not defined

# %%
print("Accuracy:",metrics.accuracy_score(y_test, predictions))

# %%
fig = plt.figure(figsize=(15, 10))
plot_tree(forest.estimators_[0], 
          feature_names=X.columns,
          class_names=df['species'].unique(), 
          filled=True, rounded=True)

plt.show()
