# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline     
sns.set(color_codes=True)

# 12-factor app
# extreme programming
# pyscript
#pipen; ouofuke (package 250W)
# django
#git branching

# %%
# Import data
#•	Via calls naar een REST API
#o	Python: requests library
#o	Handmatig: Thunder Client of curl /wget commando
#•	Via de SQLite DB
#o	Python: pysqlite library
#o	Handmatig: DB Browser

#vanuit res_server:
#chmod +x *.sh
#./install.sh
#./start_rest_server.sh
df = pd.read_csv("Data/data.csv")
display(df)
# Out:
#       Unnamed: 0  genetic  length  mass  exercise  smoking  alcohol  sugar  \
# 0              0     84.0   180.0  90.0       2.0      9.0      1.0      2
# 1              1     84.0   204.0  79.0       3.0      2.0      7.0      3
# 2              2     84.0   174.0  74.0       3.0     20.0      3.0      2
# 3              3     84.0   187.0  78.0       2.0      6.0      5.0      3
# 4              4     84.0   187.0  89.0       2.0     12.0      0.0      2
# ...          ...      ...     ...   ...       ...      ...      ...    ...
# 8187        8187     82.0   185.0  67.0       3.0     11.0      8.0      2
# 8188        8188     82.0   183.0  72.0       2.0      1.0      5.0      4
# 8189        8189     83.0   192.0  92.0       1.0     22.0      2.0      4
# 8190        8190     81.0   175.0  60.0       3.0     13.0      7.0      2
# 8191        8191     83.0   204.0  76.0       3.0      8.0      8.0      1
#
#       lifespan
# 0           86
# 1          100
# 2           87
# 3           91
# 4           83
# ...        ...
# 8187        90
# 8188        88
# 8189        62
# 8190        93
# 8191        96
#
# [8192 rows x 9 columns]

# %%
# To display the top 5 rows
df.head()
# Out:
#    Unnamed: 0  genetic  length  mass  exercise  smoking  alcohol  sugar  \
# 0           0     84.0   180.0  90.0       2.0      9.0      1.0      2
# 1           1     84.0   204.0  79.0       3.0      2.0      7.0      3
# 2           2     84.0   174.0  74.0       3.0     20.0      3.0      2
# 3           3     84.0   187.0  78.0       2.0      6.0      5.0      3
# 4           4     84.0   187.0  89.0       2.0     12.0      0.0      2
#
#    lifespan
# 0        86
# 1       100
# 2        87
# 3        91
# 4        83

# %%
# To display last 5 rows
df.tail()
# Out:
#       Unnamed: 0  genetic  length  mass  exercise  smoking  alcohol  sugar  \
# 8187        8187     82.0   185.0  67.0       3.0     11.0      8.0      2
# 8188        8188     82.0   183.0  72.0       2.0      1.0      5.0      4
# 8189        8189     83.0   192.0  92.0       1.0     22.0      2.0      4
# 8190        8190     81.0   175.0  60.0       3.0     13.0      7.0      2
# 8191        8191     83.0   204.0  76.0       3.0      8.0      8.0      1
#
#       lifespan
# 8187        90
# 8188        88
# 8189        62
# 8190        93
# 8191        96

# %%
# Check data
#df = df.drop(['Unnamed: 0'], axis=1)
df.info()
df["bmi"] = round(df["mass"]/(df["length"]/100)**2, 2)
df["factor"] = round(df["genetic"]/df["lifespan"], 2)

df = df.rename(columns={"Unnamed": "factor"})


#df["Unnamed"] = df["factor"]
bmi_bins = [0,22,28,30, np.inf]
smoking_bins = [0, 5, 10, 15, 20, np.inf]
df["bmi bins"] = pd.cut(df['bmi'],bmi_bins, labels = ["underweight", "normal", "overweight", "obese"])
#df["bmi bins"] = pd.cut(df['bmi'],bmi_bins, labels = [1, 2, 3,4])

df["smoking_bins"] = pd.cut(df['smoking'],smoking_bins, labels = ["non smoking", "5 smoking", "10 smoking", "15 smoking", " 10+smoking"])
#df["smoking"] = pd.cut(df['smoking'],smoking_bins, labels = [),1, 2, 3,4])

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8185 entries, 0 to 8191
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   genetic       8185 non-null   float64
#  1   length        8185 non-null   float64
#  2   mass          8185 non-null   float64
#  3   exercise      8185 non-null   float64
#  4   smoking       8185 non-null   float64
#  5   alcohol       8185 non-null   float64
#  6   sugar         8185 non-null   int64
#  7   lifespan      8185 non-null   int64
#  8   bmi           8185 non-null   float64
#  9   factor        8185 non-null   float64
#  10  bmi bins      8185 non-null   category
#  11  smoking_bins  7291 non-null   category
#  12  factor        8185 non-null   float64
# dtypes: category(2), float64(9), int64(2)
# memory usage: 783.7 KB
#    genetic  length  mass  exercise  smoking  alcohol  sugar  lifespan    bmi  \
# 0     84.0   180.0  90.0       2.0      9.0      1.0      2        86  27.78
# 1     84.0   204.0  79.0       3.0      2.0      7.0      3       100  18.98
# 2     84.0   174.0  74.0       3.0     20.0      3.0      2        87  24.44
# 3     84.0   187.0  78.0       2.0      6.0      5.0      3        91  22.31
# 4     84.0   187.0  89.0       2.0     12.0      0.0      2        83  25.45
#
#    factor     bmi bins smoking_bins  factor
# 0    0.98       normal    5 smoking    0.98
# 1    0.84  underweight  non smoking    0.84
# 2    0.97       normal   15 smoking    0.97
# 3    0.92       normal    5 smoking    0.92
# 4    1.01       normal   10 smoking    1.01

# %%
# Check data some more
#df["column_genetic", "column_length", "column_mass',"column_exercise", "column_alcohol", "column_sugar"] = df["column_genetic", #"column_length", "column_mass',"column_exercise", "column_alcohol", "column_sugar"].astype(float)
#df['bmi bins'].isna()
# df['bmi bins'] = df['bmi bins'].astype(int)
df.describe()
# uitschieters omhoog length, mass en exercise, alcohol hoge mean, sugar, laag, lifespan uitschieters omhoog en omlaag, genetic 79-84
# Out:
#            genetic       length         mass     exercise      smoking  \
# count  8185.000000  8185.000000  8185.000000  8185.000000  8185.000000
# mean     79.967990   183.646060    79.793158     1.616982     9.776909
# std       1.635371    12.602627    12.078802     0.831051     6.965586
# min      76.000000   154.000000    60.000000     0.000000     0.000000
# 25%      79.000000   174.000000    70.000000     1.000000     3.000000
# 50%      80.000000   183.000000    79.000000     1.000000    10.000000
# 75%      81.000000   193.000000    88.000000     2.000000    16.000000
# max      84.000000   214.000000   112.000000     4.000000    22.000000
#
#            alcohol        sugar     lifespan          bmi       factor  \
# count  8185.000000  8185.000000  8185.000000  8185.000000  8185.000000
# mean      5.747343     2.422724    76.096518    23.990051     1.072712
# std       2.664562     0.949956    10.920533     4.901931     0.156803
# min       0.000000     1.000000    40.000000    13.320000     0.710000
# 25%       4.000000     2.000000    68.000000    20.340000     0.960000
# 50%       6.000000     2.000000    76.000000    23.510000     1.050000
# 75%       8.000000     3.000000    83.000000    27.120000     1.170000
# max      10.000000     5.000000   113.000000    46.620000     2.000000
#
#            Unnamed
# count  8185.000000
# mean      1.072712
# std       0.156803
# min       0.710000
# 25%       0.960000
# 50%       1.050000
# 75%       1.170000
# max       2.000000

# %%
# Drop some columns
#df = df.drop(['Unnamed: 0'], axis=1)
#df["factor"] = df["Unnamed"]

# %%
# Rename some columns
#df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
#df.head()

# %%
# Any duplicates
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 11)

# %%
# Now what do we do with those?

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    genetic  length  mass  exercise  smoking  alcohol  sugar  lifespan    bmi  \
# 0     84.0   180.0  90.0       2.0      9.0      1.0      2        86  27.78
# 1     84.0   204.0  79.0       3.0      2.0      7.0      3       100  18.98
# 2     84.0   174.0  74.0       3.0     20.0      3.0      2        87  24.44
# 3     84.0   187.0  78.0       2.0      6.0      5.0      3        91  22.31
# 4     84.0   187.0  89.0       2.0     12.0      0.0      2        83  25.45
#
#    factor     bmi bins
# 0    0.98       normal
# 1    0.84  underweight
# 2    0.97       normal
# 3    0.92       normal
# 4    1.01       normal

# %%
# Any missing values?
print(df.isnull().sum())
# Out:
# genetic     1
# length      2
# mass        1
# exercise    1
# smoking     1
# alcohol     1
# sugar       0
# lifespan    0
# bmi         3
# factor      1
# bmi bins    3
# dtype: int64

# %%
# Why is it missing? Is it random?
# Impute or delete? Delete; zijn er weinig op hoeveelheid data

# %%
df = df.dropna()
df.head()
# Out:
#    genetic  length  mass  exercise  smoking  alcohol  sugar  lifespan    bmi  \
# 0     84.0   180.0  90.0       2.0      9.0      1.0      2        86  27.78
# 1     84.0   204.0  79.0       3.0      2.0      7.0      3       100  18.98
# 2     84.0   174.0  74.0       3.0     20.0      3.0      2        87  24.44
# 3     84.0   187.0  78.0       2.0      6.0      5.0      3        91  22.31
# 4     84.0   187.0  89.0       2.0     12.0      0.0      2        83  25.45
#
#    factor     bmi bins
# 0    0.98       normal
# 1    0.84  underweight
# 2    0.97       normal
# 3    0.92       normal
# 4    1.01       normal

# %%
#Got any outliers?
#sns.boxplot(x=df['genetic'])
#sns.boxplot(x=df['factor'])
#sns.boxplot(y=df['bmi bins'], x=df["lifespan"])
#sns.boxplot(x=df['exercise'])
sns.boxplot(y=df['smoking_bins'], x=df["lifespan"])
#sns.boxplot(x=df['alcohol'])
#sns.boxplot(x=df['sugar'])

fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['alcohol'], df['lifespan'])
ax.set_xlabel('alcohol')
ax.set_ylabel('lifespan')
plt.show()

# %%
sns.boxplot(x=df['factor'])
# Out:
# <AxesSubplot: xlabel='factor'>

# %%
sns.boxplot(x=df['bmi'])
# Out:
# <AxesSubplot: xlabel='bmi'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(Q1)
print()
print(Q3)
print()
print(IQR)
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# C:\Users\31623\AppData\Local\Temp\ipykernel_20240\1651518826.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# C:\Users\31623\AppData\Local\Temp\ipykernel_20240\1651518826.py:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)
# C:\Users\31623\AppData\Local\Temp\ipykernel_20240\1651518826.py:9: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# genetic      79.00
# length      174.00
# mass         70.00
# exercise      1.00
# smoking       3.00
# alcohol       4.00
# sugar         2.00
# lifespan     68.00
# bmi          20.34
# factor        0.96
# factor        0.96
# Name: 0.25, dtype: float64
#
# genetic      81.00
# length      193.00
# mass         88.00
# exercise      2.00
# smoking      16.00
# alcohol       8.00
# sugar         3.00
# lifespan     83.00
# bmi          27.12
# factor        1.17
# factor        1.17
# Name: 0.75, dtype: float64
#
# genetic      2.00
# length      19.00
# mass        18.00
# exercise     1.00
# smoking     13.00
# alcohol      4.00
# sugar        1.00
# lifespan    15.00
# bmi          6.78
# factor       0.21
# factor       0.21
# dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 9
#       7 print()
#       8 print(IQR)
# ----> 9 df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\frame.py:7579, in DataFrame._cmp_method(self, other, op)
#    7576 def _cmp_method(self, other, op):
#    7577     axis = 1  # only relevant for Series other case
# -> 7579     self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7581     # See GH#4537 for discussion of scalar op behavior
#    7582     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\ops\__init__.py:307, in align_method_FRAME(left, right, axis, flex, level)
#     297         if not left.axes[axis].equals(right.index):
#     298             warnings.warn(
#     299                 "Automatic reindexing on DataFrame vs Series comparisons "
#     300                 "is deprecated and will raise ValueError in a future version. "
#    (...)
#     304                 stacklevel=find_stack_level(),
#     305             )
# --> 307     left, right = left.align(
#     308         right, join="outer", axis=axis, level=level, copy=False
#     309     )
#     310     right = _maybe_align_series_as_frame(left, right, axis)
#     312 return left, right
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\frame.py:5090, in DataFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    5076 @doc(NDFrame.align, **_shared_doc_kwargs)
#    5077 def align(
#    5078     self,
#    (...)
#    5088     broadcast_axis: Axis | None = None,
#    5089 ) -> DataFrame:
# -> 5090     return super().align(
#    5091         other,
#    5092         join=join,
#    5093         axis=axis,
#    5094         level=level,
#    5095         copy=copy,
#    5096         fill_value=fill_value,
#    5097         method=method,
#    5098         limit=limit,
#    5099         fill_axis=fill_axis,
#    5100         broadcast_axis=broadcast_axis,
#    5101     )
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\generic.py:9452, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    9440     return self._align_frame(
#    9441         other,
#    9442         join=join,
#    (...)
#    9449         fill_axis=fill_axis,
#    9450     )
#    9451 elif isinstance(other, ABCSeries):
# -> 9452     return self._align_series(
#    9453         other,
#    9454         join=join,
#    9455         axis=axis,
#    9456         level=level,
#    9457         copy=copy,
#    9458         fill_value=fill_value,
#    9459         method=method,
#    9460         limit=limit,
#    9461         fill_axis=fill_axis,
#    9462     )
#    9463 else:  # pragma: no cover
#    9464     raise TypeError(f"unsupported type: {type(other)}")
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\generic.py:9587, in NDFrame._align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    9585 if lidx is not None:
#    9586     bm_axis = self._get_block_manager_axis(1)
# -> 9587     fdata = fdata.reindex_indexer(join_index, lidx, axis=bm_axis)
#    9589 if copy and fdata is self._mgr:
#    9590     fdata = fdata.copy()
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\internals\managers.py:737, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     735 # some axes don't allow reindexing with dups
#     736 if not allow_dups:
# --> 737     self.axes[axis]._validate_can_reindex(indexer)
#     739 if axis >= self.ndim:
#     740     raise IndexError("Requested axis not found in manager")
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\indexes\base.py:4316, in Index._validate_can_reindex(self, indexer)
#    4314 # trying to reindex on an axis with duplicates
#    4315 if not self._index_as_unique and len(indexer):
# -> 4316     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
df.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("smoking")
plt.ylabel('number of people')
plt.xlabel('smoking');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 df.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
#       2 plt.title("smoking")
#       3 plt.ylabel('number of people')
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\frame.py:7218, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7215 if subset is None:
#    7216     subset = self.columns.tolist()
# -> 7218 counts = self.groupby(subset, dropna=dropna).grouper.size()
#    7220 if sort:
#    7221     counts = counts.sort_values(ascending=ascending)
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\groupby\groupby.py:965, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     962 if grouper is None:
#     963     from pandas.core.groupby.grouper import get_grouper
# --> 965     grouper, exclusions, obj = get_grouper(
#     966         obj,
#     967         keys,
#     968         axis=axis,
#     969         level=level,
#     970         sort=sort,
#     971         observed=observed,
#     972         mutated=self.mutated,
#     973         dropna=self.dropna,
#     974     )
#     976 self.obj = obj
#     977 self.axis = obj._get_axis_number(axis)
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\groupby\grouper.py:883, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     879     in_axis, name, gpr = True, gpr, obj[gpr]
#     880     if gpr.ndim != 1:
#     881         # non-unique columns; raise here to get the name in the
#     882         # exception message
# --> 883         raise ValueError(f"Grouper for '{name}' not 1-dimensional")
#     884     exclusions.add(name)
#     885 elif obj._is_level_reference(gpr, axis=axis):
#
# ValueError: Grouper for 'factor' not 1-dimensional

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
# Out:
# C:\Users\31623\AppData\Local\Temp\ipykernel_20240\2194444630.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['sugar'], df['lifespan'])
ax.set_xlabel('sugar')
ax.set_ylabel('lifespan')
plt.show()
