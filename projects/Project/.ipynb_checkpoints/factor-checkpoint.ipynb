# %%
Step 2   Save DATA to suitable location.
With advice from Jeroen we understood temporary data is stored locally on your drive after analyzing DataFrame online.
Find temporary DATA in '\Project\rest_server\medisch_centrum_randstad\db.sqlite3' (depending on your USER location).
 
Step 3   Import data into SQLite and EXPORT DATA as CSV
Import scraped data (file 'db.sqlite3') into DB Browser for SQLite.
Find data from 'Tables/rest_api_netlify' and EXPORT DATA as CSV.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline     
sns.set(color_codes=True)

# 12-factor app
# extreme programming
# pyscript
#pipen; ouofuke (package 250W)
# django
#git branching

#layered architecture: presentarion-interface, logic-data pipeline, data: sql, db, model3

# %%
# Import data
#•	Via calls naar een REST API
#o	Python: requests library
#o	Handmatig: Thunder Client of curl /wget commando
#•	Via de SQLite DB
#o	Python: pysqlite library
#o	Handmatig: DB Browser

#vanuit res_server:
#chmod +x *.sh
#./install.sh
#./start_rest_server.sh
df = pd.read_csv("Data/data.csv", na_values=['?', "undefined"])
display(df)
# Out:
#       genetic  length   mass  exercise  smoking  alcohol  sugar  lifespan
# 0        73.9   185.0   99.7       0.9      0.0      2.4    6.9      73.1
# 1        86.0   172.0  105.4       1.8      8.1      0.4    4.2      85.0
# 2        83.3   176.0  111.4       1.1      0.8      4.6    7.5      81.6
# 3        82.8   164.0  111.4       4.7     11.8      1.0    2.9      81.0
# 4        78.7   178.0   71.6       1.5      8.3      4.9    5.5      75.0
# ...       ...     ...    ...       ...      ...      ...    ...       ...
# 4091     80.3   176.0  115.9       3.7      0.1      5.6    5.8      80.7
# 4092     75.3   162.0  129.6       3.6      6.2      5.6    7.6      71.1
# 4093     93.1   189.0  115.3       2.7      9.4      4.9    6.6      90.0
# 4094     77.9   170.0   90.8       2.3     13.2      0.8    6.2      75.9
# 4095    101.3   188.0  129.2       1.2      8.2      6.0    6.2      96.9
#
# [4096 rows x 8 columns]

# %%
# To display the top 5 rows
df.head()
# Out:
#   genetic length   mass exercise  smoking alcohol sugar  lifespan
# 0    73.9    185   99.7      0.9      0.0     2.4   6.9      73.1
# 1    86.0    172  105.4      1.8      8.1     0.4   4.2      85.0
# 2    83.3    176  111.4      1.1      0.8     4.6   7.5      81.6
# 3    82.8    164  111.4      4.7     11.8     1.0   2.9      81.0
# 4    78.7    178   71.6      1.5      8.3     4.9   5.5      75.0

# %%
# To display last 5 rows
df.tail()
# Out:
#      genetic length   mass exercise  smoking alcohol sugar  lifespan
# 4091    80.3    176  115.9      3.7      0.1     5.6   5.8      80.7
# 4092    75.3    162  129.6      3.6      6.2     5.6   7.6      71.1
# 4093    93.1    189  115.3      2.7      9.4     4.9   6.6      90.0
# 4094    77.9    170   90.8      2.3     13.2     0.8   6.2      75.9
# 4095   101.3    188  129.2      1.2      8.2     6.0   6.2      96.9

# %%
# Check data
#df = df.drop(['Unnamed: 0'], axis=1)
df.info()
df["bmi"] = round(df["mass"]/(df["length"]/100)**2, 2)
#df["factor"] = round(df["genetic"]/df["lifespan"], 2)

#df = df.rename(columns={"Unnamed": "factor"})


#df["Unnamed"] = df["factor"]
bmi_bins = [0,18.5,25,30, np.inf]
smoking_bins = [0, 1, 7, 10, 19, np.inf]
df["bmi bins"] = pd.cut(df['bmi'],bmi_bins, labels = ["underweight", "normal", "overweight", "obese"])
#df["bmi bins"] = pd.cut(df['bmi'],bmi_bins, labels = [18.5, 25,30])

df["smoking_bins"] = pd.cut(df['smoking'],smoking_bins, labels = ["0 smoking", "5 smoking", "10 smoking", "15 smoking", " 10+smoking"])
#df["smoking"] = pd.cut(df['smoking'],smoking_bins, labels = 0,5,10,15,20])

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4096 entries, 0 to 4095
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   genetic   4095 non-null   float64
#  1   length    4093 non-null   float64
#  2   mass      4094 non-null   float64
#  3   exercise  4095 non-null   float64
#  4   smoking   4096 non-null   float64
#  5   alcohol   4094 non-null   float64
#  6   sugar     4095 non-null   float64
#  7   lifespan  4096 non-null   float64
#  8   bmi       4091 non-null   float64
# dtypes: float64(9)
# memory usage: 288.1 KB
#    genetic  length   mass  exercise  smoking  alcohol  sugar  lifespan    bmi  \
# 0     73.9   185.0   99.7       0.9      0.0      2.4    6.9      73.1  29.13
# 1     86.0   172.0  105.4       1.8      8.1      0.4    4.2      85.0  35.63
# 2     83.3   176.0  111.4       1.1      0.8      4.6    7.5      81.6  35.96
# ...

# %%
# Check data some more
#df["column_genetic", "column_length", "column_mass',"column_exercise", "column_alcohol", "column_sugar"] = #df["column_genetic", #"column_length", "column_mass',"column_exercise", "column_alcohol", "column_sugar"].astype(float): werkt niet binnenhalen al geen datum
#df['bmi bins'].isna(): werkt niet
# df['bmi bins'] = df['bmi bins'].astype(int): kan niet is een categorie


for x in df.index:
  if df.loc[x, "lifespan"] < 0:
    df.drop(x, inplace = True)

df["lifespan"]>1
df.describe()
# genetic meer spreiding dan vorige dataset, lange en dus zware mensen, max oef 5,5 uur, smoking laag maz, alcohol best veel, life span -1, grotere spreiding, sugar meer dan vorige, bmi max hoog, mass max ook
#drop min. lifespan
# Out:
#            genetic       length         mass     exercise      smoking  \
# count  4031.000000  4031.000000  4031.000000  4031.000000  4031.000000
# mean     82.273580   183.905979    92.273977     2.405061     9.938005
# std       7.443717    12.623498    25.854439     1.169986     6.871296
# min      63.900000   154.000000    50.000000     0.100000     0.100000
# 25%      77.600000   175.000000    71.300000     1.500000     3.700000
# 50%      81.800000   184.000000    89.500000     2.200000     9.700000
# 75%      86.700000   193.000000   110.900000     3.200000    16.000000
# max     102.200000   214.000000   163.600000     5.500000    22.200000
#
#            alcohol        sugar     lifespan          bmi       factor
# count  4031.000000  4031.000000  4031.000000  4031.000000  4031.000000
# mean      2.264103     6.489159    80.138700    27.675723     1.027822
# std       1.799695     2.708618     7.842029     8.720578     0.032457
# ...

# %%
# Drop some columns
#df = df.drop(['length: 1', "mass: 2"], axis=1) 
#df["factor"] = df["Unnamed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 2
#       1 # Drop some columns
# ----> 2 df = df.drop(['length: 1', "mass: 2"], axis=1)
#       3 #df["factor"] = df["Unnamed"]
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\MakeAIWorkGab\env\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
# Rename some columns
#df = df.title
#df = df.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
#df.head()

# %%
# Any duplicates# ja, weinig op gehele set dus gedropt
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 11)

# %%
# Now what do we do with those?

# %%
df = df.drop_duplicates()
df.head()
# Out:
#    genetic  length   mass  exercise  smoking  alcohol  sugar  lifespan    bmi  \
# 0     73.9   185.0   99.7       0.9      0.0      2.4    6.9      73.1  29.13
# 1     86.0   172.0  105.4       1.8      8.1      0.4    4.2      85.0  35.63
# 2     83.3   176.0  111.4       1.1      0.8      4.6    7.5      81.6  35.96
# 3     82.8   164.0  111.4       4.7     11.8      1.0    2.9      81.0  41.42
# 4     78.7   178.0   71.6       1.5      8.3      4.9    5.5      75.0  22.60
#
#      bmi bins smoking_bins  factor
# 0  overweight          NaN    1.01
# 1       obese    5 smoking    1.01
# 2       obese    0 smoking    1.02
# 3       obese   10 smoking    1.02
# 4      normal    5 smoking    1.05

# %%
# Any missing values? ja weinig op gehele set dus gedropt
print(df.isnull().sum())
# Out:
# genetic          1
# length           3
# mass             2
# exercise         1
# smoking          0
# alcohol          2
# sugar            1
# lifespan         0
# bmi              5
# bmi bins         5
# smoking_bins    54
# dtype: int64

# %%
# Why is it missing? Is it random?
# Impute or delete? Delete; zijn er weinig op hoeveelheid data

# %%
df = df.dropna()
#df.head()

# %%
#Got any outliers?
#sns.boxplot(x=df['genetic']) een paar
#sns.boxplot(x=df['lifespan']) ja
#sns.boxplot(y=df['bmi bins'], x=df["lifespan"])#weinig verschil in bins, wel underweight nu neg. op lifespan
#sns.boxplot(x=df['exercise'])nee
#sns.boxplot(y=df['smoking_bins'], x=df["lifespan"]) verschil in bins
#sns.boxplot(x=df['alcohol'])nee
#sns.boxplot(x=df['bmi']) ja
#sns.boxplot(x=df['smoking']) nee
#sns.boxplot(x=df['factor']) een paar


fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['bmi'], df['lifespan'])
ax.set_xlabel('bmi')
ax.set_ylabel('lifespan')
plt.show()

# %%
fig, axes = plt.subplots(4, 2, figsize=(15, 15))
fig.suptitle('Histograms')
sns.histplot(ax=axes[0, 0], x=df['genetic'])
sns.histplot(ax=axes[0, 1], x=df['length'])
sns.histplot(ax=axes[1, 0], x=df['mass'])
sns.histplot(ax=axes[1, 1], x=df['exercise'])
sns.histplot(ax=axes[2, 0], x=df['smoking'])
sns.histplot(ax=axes[2, 1], x=df['alcohol'])
sns.histplot(ax=axes[3, 0], x=df['sugar'])
sns.histplot(ax=axes[3, 1], x=df['lifespan'])

# %%
# Out:
#   Cell In[61], line 2
#     ax.scatter(df['bmi bins"], df['lifespan"])
#                                            ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
sns.boxplot(x=df['smoking'])
# Out:
# <AxesSubplot: xlabel='smoking'>

# %%
sns.boxplot(x=df['bmi'])
# Out:
# <AxesSubplot: xlabel='bmi'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(Q1)
print()
print(Q3)
print()
print(IQR)
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

#trainen met dataset met en zonder IQR, zonder factor gebruiken voor model/check, met en zonder lengte/gewicht
# Out:
# genetic      77.60
# length      175.00
# mass         71.30
# exercise      1.50
# smoking       3.70
# alcohol       0.60
# sugar         4.40
# lifespan     75.00
# bmi          20.91
# factor        1.00
# Name: 0.25, dtype: float64
#
# genetic      86.70
# length      193.00
# mass        110.90
# exercise      3.20
# smoking      16.00
# alcohol       4.00
# sugar         8.40
# lifespan     85.10
# bmi          33.23
# factor        1.05
# Name: 0.75, dtype: float64
#
# genetic      9.10
# length      18.00
# mass        39.60
# exercise     1.70
# smoking     12.30
# alcohol      3.40
# sugar        4.00
# lifespan    10.10
# bmi         12.32
# factor       0.05
# dtype: float64
# C:\Users\31623\AppData\Local\Temp\ipykernel_21420\3461889481.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
df.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("bmi bin")
plt.ylabel('number of people')
plt.xlabel('bmi bin');

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)

# correlatie genetics is minder, correlatie factor is veel minder, mn correlatie roken, correlatie mn met roken, niet meer met exercise en bmi
# Out:
# C:\Users\31623\AppData\Local\Temp\ipykernel_21420\3649862284.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['smoking'], df['lifespan'])
ax.set_xlabel('smoking')
ax.set_ylabel('lifespan')
plt.show()
